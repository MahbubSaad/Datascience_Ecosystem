# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook  a brief overview of Data Science tools and Ecosystem will be presented.

# %% [markdown]
# **Objectives**
#
# + Knowing about popular languages that Data scientists usually use.
# + Knowing about some common libraries containing some useful builtin funtions that make complex tasks easier.
# + Knowing about some free opensource tools that can be used for developlment environment.
# + Practising some arithmetic expression

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. Java
# 4. Julia

# %% [markdown]
# Data Scientists use different libraries to do complex tasks easier, faster and more accurately as Libraries offers some prebuilt functions. Some of the commonly used libraries in data science are
# 1. Numpy
# 2. Matplotlib
# 3. Pandas
# 4. Scikit learn

# %% [markdown]
# There some free open source tools are used for development environment. Some common tools are,
#
# | Sl. | Data Science Tools |
# |-----|--------------------|
# | 1. | Jupyter Notebook |
# | 2. | RStudio |
# | 3. | VS Code |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This is a simple arithmetic expression to multiply and then add integers
"""x= 3
y= 4
z= 5
result = (x*y)+z
print (result)"""
3*4+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60

minute= 200
second_converter = minute*60
print (second_converter)
# Out:
# 12000

# %% [markdown]
# ## Author
# S.M Mahbub Murshed
